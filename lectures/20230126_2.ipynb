# %%
from encore import get_stock
from encore import head

# %%
rt = get_stock("035720", 1, 4)

# %%
import csv
import requests
import tqdm

# %%
f = open("./삼성전자.csv", "a", encoding="utf-8", newline="")
wr = csv.writer(f)
wr.writerows(rt)
f.close()

# %%
url = "http://data.krx.co.kr/comm/bldAttendant/getJsonData.cmd"
payload = {"bld":"dbms/MDC/STAT/standard/MDCSTAT01501",
"locale":"ko_KR",
"mktId":"ALL",
"trdDd":"20230126",
"share":"1",
"money":"1",
"csvxls_isNo":"false",}

# %%
r = requests.post(url, headers=head, data=payload)

# %%
j = r.json()

# %%
j['OutBlock_1'][0]["ISU_ABBRV"]
# Out:
# '3S'

# %%
import time
import random

# %%
random.randint(1, 6)
# Out:
# 4

# %%
time.sleep(random.randint(1, 7))

# %%
len(krx.json()["OutBlock_1"])
# Out:
# 2693

# %%
def all_stocks(krx):
    for x in krx:
        rt = get_stock(x["ISU_SRT_CD"], 1, 10)
        f = open("./all_stocks_2/{}.csv".format(x["ISU_ABBRV"]), "w", encoding="utf-8", newline="")
        wr = csv.writer(f)
        wr.writerows(rt)
        f.close()
    return 0

# %%
all_stocks(krx.json()["OutBlock_1"])
# Out:
# 0

# %% [markdown]
# # pickle 저장

# %%
import pickle

# %%
with open("./krx.pkl", "rb") as f:
    krx = pickle.load(f)

# %%
krx.json()["OutBlock_1"]
# Out:
# [{'ISU_SRT_CD': '060310',
#   'ISU_CD': 'KR7060310000',
#   'ISU_ABBRV': '3S',
#   'MKT_NM': 'KOSDAQ',
#   'SECT_TP_NM': '중견기업부',
#   'TDD_CLSPRC': '2,285',
#   'FLUC_TP_CD': '3',
#   'CMPPREVDD_PRC': '0',
#   'FLUC_RT': '0.00',
#   'TDD_OPNPRC': '2,290',
#   'TDD_HGPRC': '2,300',
#   'TDD_LWPRC': '2,265',
#   'ACC_TRDVOL': '81,517',
#   'ACC_TRDVAL': '186,101,260',
#   'MKTCAP': '110,906,226,970',
#   'LIST_SHRS': '48,536,642',
#   'MKT_ID': 'KSQ'},
#  {'ISU_SRT_CD': '095570',
#   'ISU_CD': 'KR7095570008',
#   'ISU_ABBRV': 'AJ네트웍스',
#   'MKT_NM': 'KOSPI',
#   'SECT_TP_NM': '',
#   'TDD_CLSPRC': '6,110',
#   'FLUC_TP_CD': '1',
#   'CMPPREVDD_PRC': '40',
#   'FLUC_RT': '0.66',
#   'TDD_OPNPRC': '6,090',
#   'TDD_HGPRC': '6,230',
#   'TDD_LWPRC': '6,030',
#   'ACC_TRDVOL': '273,951',
#   'ACC_TRDVAL': '1,680,251,260',
#   'MKTCAP': '286,084,222,450',
#   'LIST_SHRS': '46,822,295',
#   'MKT_ID': 'STK'},
#  {'ISU_SRT_CD': '006840',
#   'ISU_CD': 'KR7006840003',
#   'ISU_ABBRV': 'AK홀딩스',
# ...

# %% [markdown]
# # lambda

# %%
def get_calc(x):
    return x**2

# %%
list(map(get_calc,[1, 2, 3, 4, 5, 6]))
# Out:
# [1, 4, 9, 16, 25, 36]

# %%
list(map(lambda x: x**2,[1, 2, 3, 4, 5, 6]))
# Out:
# [1, 4, 9, 16, 25, 36]

# %%
sum(map(lambda x: int(x.replace(",", "")),['113,310','234,10','1052,142','1,205,520']))
# Out:
# 2394382

# %%
(lambda x, y: x + y)(3, 4)
# Out:
# 7

# %%
(lambda x, y: x + y if x % 2 == 0 else x * y)(3, 4)
# Out:
# 12

# %% [markdown]
# # 스타벅스 API 찾기

# %%
from bs4 import BeautifulSoup as BS

# %%
api1 = "https://www.starbucks.co.kr/store/getGugunList.do"
api2 = "https://www.starbucks.co.kr/store/getStore.do?r=5IM0DC03EA"

# %%
api1_data = {"sido_cd":"01",
"rndCod":"6NQ3YSTF02"}
api2_data = {
"in_biz_cds":"0",
"in_scodes":"0",
"ins_lat":"37.4684292",
"ins_lng":"126.8863204",
"search_text":"",
"p_sido_cd":"01",
"p_gugun_cd":"",
"isError":"true",
"in_distance":"0",
"in_biz_cd":"",
"iend":"1000",
"searchType":"C",
"set_date":"",
"rndCod":"GXBQD9G4NG",
"all_store":"0",
"T03":"0",
"T01":"0",
"T27":"0",
"T12":"0",
"T09":"0",
"T30":"0",
"T05":"0",
"T22":"0",
"T21":"0",
"T10":"0",
"T36":"0",
"T43":"0",
"T48":"0",
"P10":"0",
"P50":"0",
"P20":"0",
"P60":"0",
"P30":"0",
"P70":"0",
"P40":"0",
"P80":"0",
"whcroad_yn":"0",
"P90":"0",
"new_bool":"0",
}

# %%
r1 = requests.post(api1, data = api1_data)
r2 = requests.post(api2, data = api2_data)

# %%
j1 = r1.json()
j1["list"]
# Out:
# [{'seq': 0,
#   'sido_cd': None,
#   'sido_nm': None,
#   'gugun_cd': '0101',
#   'gugun_nm': '강남구',
#   'code_order': None,
#   'view_yn': None,
#   'store_num': None,
#   'sido': None,
#   'gugun': None,
#   'address': None,
#   'new_img_nm': None,
#   'p_pro_seq': 0,
#   'p_view_yn': None,
#   'p_sido_cd': '',
#   'p_gugun_cd': '',
#   'p_store_nm': None,
#   'p_theme_cd': None,
#   'p_wireless_yn': None,
#   'p_smoking_yn': None,
#   'p_book_yn': None,
#   'p_music_yn': None,
#   'p_terrace_yn': None,
#   'p_table_yn': None,
#   'p_takeout_yn': None,
#   'p_parking_yn': None,
#   'p_dollar_assent': None,
#   'p_card_recharge': None,
#   'p_subway_yn': None,
#   'stb_store_file_renew': None,
#   'stb_store_theme_renew': None,
#   'stb_store_time_renew': None,
#   'stb_store_lsm': None,
#   's_code': None,
#   's_name': None,
#   'tel': None,
#   'fax': None,
#   'sido_code': None,
#   'sido_name': None,
#   'gugun_code': None,
#   'gugun_name': None,
#   'addr': None,
# ...

# %%
j2 = r2.json()
j2["list"]
# Out:
# [{'seq': 0,
#   'sido_cd': None,
#   'sido_nm': None,
#   'gugun_cd': None,
#   'gugun_nm': None,
#   'code_order': None,
#   'view_yn': None,
#   'store_num': None,
#   'sido': None,
#   'gugun': None,
#   'address': None,
#   'new_img_nm': None,
#   'p_pro_seq': 0,
#   'p_view_yn': None,
#   'p_sido_cd': '',
#   'p_gugun_cd': '',
#   'p_store_nm': None,
#   'p_theme_cd': None,
#   'p_wireless_yn': None,
#   'p_smoking_yn': None,
#   'p_book_yn': None,
#   'p_music_yn': None,
#   'p_terrace_yn': None,
#   'p_table_yn': None,
#   'p_takeout_yn': None,
#   'p_parking_yn': None,
#   'p_dollar_assent': None,
#   'p_card_recharge': None,
#   'p_subway_yn': None,
#   'stb_store_file_renew': None,
#   'stb_store_theme_renew': None,
#   'stb_store_time_renew': None,
#   'stb_store_lsm': None,
#   's_code': '1509',
#   's_name': '역삼아레나빌딩',
#   'tel': '1522-3232',
#   'fax': '02-568-3763',
#   'sido_code': '01',
#   'sido_name': '서울',
#   'gugun_code': '0101',
#   'gugun_name': '강남구',
# ...

# %%
file_names = [x["defaultimage"] for x in j2["list"]]

# %%
file_names
# Out:
# ['/upload/store/2020/09/[3762]_20200917031519_6juwr.JPG',
#  '/upload/store/2018/12/[3672]_20181211120009_t9i9n.jpg',
#  '/upload/store/2022/01/[3858]_20220127064243_5khni.jpg',
#  '/upload/store/2019/07/[3669]_20190730073527_5nk40.jpg',
#  '/upload/store/2019/02/[3703]_20190215093408_m3pv1.jpg',
#  '/upload/store/2020/05/[3912]_20200527074116_twz04.jpg',
#  '/upload/store/2021/08/[3893]_20210828042809_9v371.jpg',
#  '/upload/store/2020/04/[3897]_20200416024102_gur3n.jpg',
#  '/upload/store/2019/04/[3648]_20190416114636_1vz1i.jpg',
#  '/upload/store/2019/11/[3623]_20191125073032_uaqua.jpg',
#  '/upload/store/2018/06/[3588]_20180625121751_b9cya.JPG',
#  '/upload/store/2020/07/[3604]_20200703010217_yqu8z.jpg',
#  '/upload/store/2018/03/[3562]_20180326063222_r20gs.jpg',
#  '/upload/store/2018/04/[3564]_20180417045105_xv16y.jpg',
#  '/upload/store/2017/08/[3483]_20170818074753_u95cx.jpg',
#  '/upload/store/2018/02/[3467]_20180226085535_lizi2.jpg',
# ...

# %%
default_url = "https://www.starbucks.co.kr/"

# %%
import os

# %%
len((file_names))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7072\1515337333.py in <module>
# ----> 1 len(enumerate(file_names))
#
# TypeError: object of type 'enumerate' has no len()

# %%
if os.path.isdir("./starbucks") is False:
    os.mkdir("./starbucks")
for idx, x in enumerate(tqdm.tqdm(file_names)):
    image = open(f"./starbucks/{idx}.jpg", "wb")
    r = requests.get(f"{default_url + x}")
    image.write(r.content)
    image.close()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 599/599 [00:47<00:00, 12.61it/s]
