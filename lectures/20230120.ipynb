# %%
text = input()

if text == text[::-1]:
    print("앞에서 읽어도 뒤에서 읽어도 같음")
# Out:
# 기러기
# 앞에서 읽어도 뒤에서 읽어도 같음

# %%
0.1 + 0.2
# Out:
# 0.30000000000000004

# %%
True or False and not False
# Out:
# True

# %%
list(range(0, 10, 2))
# Out:
# [0, 2, 4, 6, 8]

# %%
for a in range(0, 100, 2):
    print(a**2)
# Out:
# 0
# 4
# 16
# 36
# 64
# 100
# 144
# 196
# 256
# 324
# 400
# 484
# 576
# 676
# 784
# 900
# 1024
# 1156
# 1296
# 1444
# 1600
# 1764
# 1936
# 2116
# 2304
# 2500
# 2704
# 2916
# 3136
# 3364
# 3600
# 3844
# 4096
# 4356
# 4624
# 4900
# 5184
# 5476
# 5776
# 6084
# 6400
# 6724
# 7056
# 7396
# 7744
# 8100
# 8464
# 8836
# 9216
# 9604

# %%
for x in range(2, 10):
    if(x%2 == 0 or x%3 == 0):
        for y in range(1, 10):
            print("{} x {} = {}".format(x, y, x*y))
# Out:
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 8 x 1 = 8
# 8 x 2 = 16
# 8 x 3 = 24
# 8 x 4 = 32
# 8 x 5 = 40
# 8 x 6 = 48
# 8 x 7 = 56
# 8 x 8 = 64
# 8 x 9 = 72
# 9 x 1 = 9
# 9 x 2 = 18
# 9 x 3 = 27
# 9 x 4 = 36
# 9 x 5 = 45
# 9 x 6 = 54
# 9 x 7 = 63
# 9 x 8 = 72
# 9 x 9 = 81

# %%
lst = []
for year in range(1800, 2201):
    if year%4 == 0 and (year%100 != 0) or (year%400 == 0):
        print(year, end=", ")
        lst.append(year)
# Out:
# 1804, 1808, 1812, 1816, 1820, 1824, 1828, 1832, 1836, 1840, 1844, 1848, 1852, 1856, 1860, 1864, 1868, 1872, 1876, 1880, 1884, 1888, 1892, 1896, 1904, 1908, 1912, 1916, 1920, 1924, 1928, 1932, 1936, 1940, 1944, 1948, 1952, 1956, 1960, 1964, 1968, 1972, 1976, 1980, 1984, 1988, 1992, 1996, 2000, 2004, 2008, 2012, 2016, 2020, 2024, 2028, 2032, 2036, 2040, 2044, 2048, 2052, 2056, 2060, 2064, 2068, 2072, 2076, 2080, 2084, 2088, 2092, 2096, 2104, 2108, 2112, 2116, 2120, 2124, 2128, 2132, 2136, 2140, 2144, 2148, 2152, 2156, 2160, 2164, 2168, 2172, 2176, 2180, 2184, 2188, 2192, 2196,

# %%
dir(lst)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
for x in range(1800, 2200, 4):
    if not(x%100 == 0 and x%400 != 0):
        print(x, end=",")
# Out:
# 1804,1808,1812,1816,1820,1824,1828,1832,1836,1840,1844,1848,1852,1856,1860,1864,1868,1872,1876,1880,1884,1888,1892,1896,1904,1908,1912,1916,1920,1924,1928,1932,1936,1940,1944,1948,1952,1956,1960,1964,1968,1972,1976,1980,1984,1988,1992,1996,2000,2004,2008,2012,2016,2020,2024,2028,2032,2036,2040,2044,2048,2052,2056,2060,2064,2068,2072,2076,2080,2084,2088,2092,2096,2104,2108,2112,2116,2120,2124,2128,2132,2136,2140,2144,2148,2152,2156,2160,2164,2168,2172,2176,2180,2184,2188,2192,2196,

# %%
total2 = [x for x in range(2, 10, 2)]
total2
# Out:
# [2, 4, 6, 8]

# %%
[num for num in range(100) if num % 7 == 0 and num % 2 == 0]
# Out:
# [0, 14, 28, 42, 56, 70, 84, 98]

# %%
total5 = tuple(total2)

# %%
total5
# Out:
# (2, 4, 6, 8)

# %%
dir(total5[2])
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
#  '__xor__',
# ...

# %% [markdown]
# # dict(사전)
# * key - value
# * {}

# %%
dict_1 = {"encore" : 100}

# %%
dict_1["encore"]
# Out:
# 100

# %%
dict_1["encore"] = 100

# %%
dict_1['aaaa'] = 200

# %%
dict_1
# Out:
# {'encore': 100, 'aaaa': 200}

# %%
import requests

# %%
url= 'https://www.starbucks.co.kr/store/getStore.do?r=804IUG79N7'

# %%
payload = {
    'in_biz_cds' : '0',
    'in_scodes' : '0',
    'ins_lat' : '37.5627128',
    'ins_lng' : '126.93279869999999',
    'search_text' : '',
    'p_sido_cd' : '01',
    'p_gugun_cd' : '',
    'in_distance' : '0',
    'in_biz_cd' : '',
    'isError' : 'true',
    'searchType' : 'C',
    'set_date' : '',
    'all_store' : '0',
    'T03' : '0',
    'T01' : '0',
    'T12' : '0',
    'T09' : '0',
    'T30' : '0',
    'T05' : '0',
    'T22' : '0',
    'T21' : '0',
    'T10' : '0',
    'T36' : '0',
    'P10' : '0',
    'P50' : '0',
    'P20' : '0',
    'P60' : '0',
    'P30' : '0',
    'P70' : '0',
    'P40' : '0',
    'P80' : '0',
    'whcroad_yn' : '0',
    'P90' : '0',
    'new_bool' : '0',
    'iend' : '1000',
    'rndCod' : 'V8UNZFKU44',}

# %%
r = requests.post(url, data=payload)

# %%
for x in r.json()['list']:
    print(f"{x['s_name']} \t {x['addr']}" )
# Out:
# 역삼아레나빌딩 	 서울특별시 강남구 역삼동 721-13 아레나빌딩
# 논현역사거리 	 서울특별시 강남구 논현동 142-2 정일빌딩
# 신사역성일빌딩 	 서울특별시 강남구 논현동 18-4 성일빌딩
# 국기원사거리 	 서울특별시 강남구 역삼동 648-22 동찬빌딩
# 대치재경빌딩R 	 서울특별시 강남구 대치동 599 대원빌딩
# 봉은사역 	 서울특별시 강남구 삼성동 108-6 JBK TOWER 빌딩
# 압구정윤성빌딩 	 서울특별시 강남구 신사동 592 윤성빌딩
# 코엑스별마당 	 서울특별시 강남구 삼성동 159 코엑스
# 삼성역섬유센터R 	 서울특별시 강남구 대치동 944-31 한국섬유산업연합회
# 압구정R 	 서울특별시 강남구 신사동 621-1
# 수서역R 	 서울특별시 강남구 수서동 715 수서빌딩
# 양재강남빌딩R 	 서울특별시 강남구 도곡동 956 LG전자 강남R&D센터
# 선릉동신빌딩R 	 서울특별시 강남구 삼성동 141-28 동신빌딩
# 봉은사로선정릉 	 서울특별시 강남구 삼성동 114-9 올림푸스타워
# 강남오거리 	 서울특별시 강남구 역삼동 813-17 1,2,3층
# 스타필드코엑스몰R 	 서울특별시 강남구 삼성동 159 코엑스  A106호
# 강남구청정문 	 서울특별시 강남구 청담동 44-12 대륭빌딩
# 도곡공원 	 서울특별시 강남구 역삼동 788-10
# 강남R 	 서울특별시 강남구 역삼동 825 미진프라자 1층 101호
# 대치은마사거리 	 서울특별시 강남구 대치동 941-19 진흥빌딩
# 청담영동대로 	 서울특별시 강남구 청담동 132-1 삼청빌딩
# 압구정 	 서울특별시 강남구 신사동 609 이소니프라자
# 신사가로수 	 서울특별시 강남구 신사동 533-11
# 청담스타R 	 서울특별시 강남구 청담동 89-4
# 강남우성 	 서울특별시 강남구 역삼동 832-3 강남역 쉐르빌
# 학동사거리 	 서울특별시 강남구 논현2동 93-2번지
# 대치사거리 	 서울특별시 강남구 대치동 960-5 티아빌딩
# ...

# %%
for x in r.json()['list']:
    if x['s_name'][-1] == "R":
        print(f"{x['s_name']} \t {x['addr']}" )
# Out:
# 대치재경빌딩R 	 서울특별시 강남구 대치동 599 대원빌딩
# 삼성역섬유센터R 	 서울특별시 강남구 대치동 944-31 한국섬유산업연합회
# 압구정R 	 서울특별시 강남구 신사동 621-1
# 수서역R 	 서울특별시 강남구 수서동 715 수서빌딩
# 양재강남빌딩R 	 서울특별시 강남구 도곡동 956 LG전자 강남R&D센터
# 선릉동신빌딩R 	 서울특별시 강남구 삼성동 141-28 동신빌딩
# 스타필드코엑스몰R 	 서울특별시 강남구 삼성동 159 코엑스  A106호
# 강남R 	 서울특별시 강남구 역삼동 825 미진프라자 1층 101호
# 청담스타R 	 서울특별시 강남구 청담동 89-4
# SSG마켓도곡R 	 서울특별시 강남구 도곡동 467-17 타워팰리스Ⅱ F 지하1층
# 센터필드R 	 서울특별시 강남구 역삼동 676 센터필드
# 마곡사이언스타워R 	 서울특별시 강서구 마곡동 796-3 마곡사이언스타워
# 관악서울대입구R 	 서울특별시 관악구 봉천동 856-6 BS타워
# 보라매공원R 	 서울특별시 동작구 신대방동 395-65 파크스퀘어,보라매현대APT
# 홍대입구역사거리R 	 서울특별시 마포구 서교동 353-5 경남관광빌딩
# 합정폴리스R 	 서울특별시 마포구 서교동 490 메세나폴리스 B189~193
# 이대R 	 서울특별시 서대문구 대현동 54-4
# 강남교보타워R 	 서울특별시 서초구 서초동 1303-22 교보타워
# 강남대로논현R 	 서울특별시 서초구 반포동 736-2 대유빌딩
# 파미에파크R 	 서울특별시 서초구 반포동 118-3 센트럴시티 파미에파크돔 BP4-9호
# 문정법원로R 	 서울특별시 송파구 문정동 642 송파 테라타워2
# 잠실대교남단R 	 서울특별시 송파구 신천동 7-30 타워730 1층
# 타임스퀘어R 	 서울특별시 영등포구 영등포동4가 442 타임스퀘어
# 여의도IFC몰(L1)R 	 서울특별시 영등포구 여의도동 23 서울 국제금융 센터 지하1층 178호
# 여의도KBS R 	 서울특별시 영등포구 여의도동 17-9
# ...

# %%
for x in r.json()['list']:
    if x['addr'].find("금천구") != -1:
        print(f"{x['s_name']} \t {x['addr']}")
# Out:
# 금천구청역 	 서울특별시 금천구 시흥동 1031 엠메디컬타워 112,113,114,115호
# 가산에스케이 	 서울특별시 금천구 가산동 371-41 가산 에스케이 브이원 센터
# 독산사거리 	 서울특별시 금천구 독산동 159-23 영진빌딩
# 금천시흥 	 서울특별시 금천구 시흥동 904-22 더플레이스
# 가산디지털단지역 	 서울특별시 금천구 가산동 50-3 대륭포스트타워6차
# 금천독산 	 서울특별시 금천구 독산동 291-1
# 가산디지털 	 서울특별시 금천구 가산동 371-28
# W-Mall 	 서울특별시 금천구 가산동 60-27 W-MALL내 지하1층
# 마리오아울렛 	 서울특별시 금천구 가산동 60-20 ㈜마리오 3관1층
# 가산브이타워 	 서울특별시 금천구 가산동 V-TOWER 371-37
# 가산그레이트 	 서울특별시 금천구 가산동 60-5 갑을그레이트벨리 1층
# 독산역 	 서울특별시 금천구 가산동 673, 107-2, 108, 109호
# 가산현대아울렛 	 서울특별시 금천구 가산동 60-8 현대시티아울렛 가산점, 1층 일부

# %%
for x in r.json()['list']:
    if "금천구" in x['addr']:
        print(f"{x['s_name']} \t {x['addr']}")
# Out:
# 금천구청역 	 서울특별시 금천구 시흥동 1031 엠메디컬타워 112,113,114,115호
# 가산에스케이 	 서울특별시 금천구 가산동 371-41 가산 에스케이 브이원 센터
# 독산사거리 	 서울특별시 금천구 독산동 159-23 영진빌딩
# 금천시흥 	 서울특별시 금천구 시흥동 904-22 더플레이스
# 가산디지털단지역 	 서울특별시 금천구 가산동 50-3 대륭포스트타워6차
# 금천독산 	 서울특별시 금천구 독산동 291-1
# 가산디지털 	 서울특별시 금천구 가산동 371-28
# W-Mall 	 서울특별시 금천구 가산동 60-27 W-MALL내 지하1층
# 마리오아울렛 	 서울특별시 금천구 가산동 60-20 ㈜마리오 3관1층
# 가산브이타워 	 서울특별시 금천구 가산동 V-TOWER 371-37
# 가산그레이트 	 서울특별시 금천구 가산동 60-5 갑을그레이트벨리 1층
# 독산역 	 서울특별시 금천구 가산동 673, 107-2, 108, 109호
# 가산현대아울렛 	 서울특별시 금천구 가산동 60-8 현대시티아울렛 가산점, 1층 일부

# %%
for x in r.json()['list']:
    print(f"{x['s_name']} \t {x['open_dt']}")
# Out:
# 역삼아레나빌딩 	 20190613
# 논현역사거리 	 20181123
# 신사역성일빌딩 	 20191219
# 국기원사거리 	 20190731
# 대치재경빌딩R 	 20190214
# 봉은사역 	 20200528
# 압구정윤성빌딩 	 20200529
# 코엑스별마당 	 20200416
# 삼성역섬유센터R 	 20181123
# 압구정R 	 20180831
# 수서역R 	 20180627
# 양재강남빌딩R 	 20180824
# 선릉동신빌딩R 	 20180330
# 봉은사로선정릉 	 20180306
# 강남오거리 	 20170818
# 스타필드코엑스몰R 	 20170502
# 강남구청정문 	 20170323
# 도곡공원 	 20170825
# 강남R 	 20170816
# 대치은마사거리 	 20160812
# 청담영동대로 	 20161223
# 압구정 	 20160623
# 신사가로수 	 20161227
# 청담스타R 	 20161214
# 강남우성 	 20161110
# 학동사거리 	 20150911
# 대치사거리 	 20160512
# 포스코사거리 	 20160224
# 을지병원사거리 	 20150422
# 신사역 	 20141211
# 도곡역 	 20140828
# 서울세관사거리 	 20140731
# 청담사거리 	 20140220
# 한티역 	 20131108
# 역삼초교사거리 	 20140326
# 코엑스몰 	 20140301
# 가로수길 	 20131004
# 역삼대로 	 20130625
# 역삼포스코 	 20130709
# 강남대로 	 20130620
# 청담 	 20130917
# 삼성도심공항 	 20130723
# 삼성교 	 20130423
# 학동역 	 20040830
# 대치 	 20030509
# SSG마켓도곡R 	 20030115
# 삼성 	 20020329
# 선릉세화빌딩 	 20011110
# 압구정역 	 20010310
# 압구정로 	 20071221
# 구역삼사거리 	 20080528
# 큰길타워 	 20050310
# ...

# %%
day = sys.maxsize
for x in r.json()['list']:
    if int(x["open_dt"]) < day:
        day = int(x["open_dt"])
        place = x
print(f"{place['s_name']} \t {place['addr']} \t {place['open_dt']}")
# Out:
# 이대R 	 서울특별시 서대문구 대현동 54-4 	 19990727
